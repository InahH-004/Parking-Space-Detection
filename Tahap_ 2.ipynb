# %% [markdown]
# <a href="https://colab.research.google.com/github/InahH-004/Parking-Space-Detection/blob/Jeje/Tahap_%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Init

# %%
#!pip install --upgrade kaggle

# %% [markdown]
# Setelah menginstal pustaka, Anda perlu menyiapkan kredensial API Kaggle Anda.
#
# 1.  Buka [Kaggle](https://www.kaggle.com/) dan masuk.
# 2.  Klik gambar profil Anda di sudut kanan atas dan pilih 'My Account'.
# 3.  Gulir ke bawah ke bagian 'API' dan klik 'Create New API Token'. Ini akan mengunduh file `kaggle.json`.
# 4.  Buka file `kaggle.json` dengan editor teks. Ini akan berisi nama pengguna dan kunci API Anda.
# 5.  Di Colab, buka tab 'Secrets' (ikon kunci 🔑 di panel kiri).
# 6.  Tambahkan dua rahasia baru:
#     *   `KAGGLE_USERNAME`: Nama pengguna Anda dari `kaggle.json`.
#     *   `KAGGLE_KEY`: Kunci API Anda dari `kaggle.json`.
# 7.  Kemudian, jalankan sel berikut untuk mengkonfigurasi klien API Kaggle.

# %% [markdown]
# ## Import Token
# ini pakai token masing-masing di kaggle

# %%
import os
from google.colab import userdata

# Buat direktori .kaggle jika belum ada
# !mkdir -p ~/.kaggle

# Tulis konten kaggle.json menggunakan rahasia userdata
# Ini membuat file kaggle.json di lokasi yang benar dengan kredensial Anda
kaggle_json_content = f'{{"username":"{userdata.get("Parkinglot")}","key":"{userdata.get("Parkinglot")}"}}'
with open('/root/.kaggle/kaggle.json', 'w') as f:
    f.write(kaggle_json_content)

# Atur izin yang sesuai
# !chmod 600 ~/.kaggle/kaggle.json

print("Kredensial Kaggle API telah dikonfigurasi.")
# Out:
# Kredensial Kaggle API telah dikonfigurasi.

# %% [markdown]
# ## Import Dataset

# %%
import os

DATASET_PATH = "./data"
if not os.path.exists(DATASET_PATH):
    # !kaggle datasets download -d trainingdatapro/parking-space-detection-dataset --unzip -p {DATASET_PATH}
    print("Dataset berhasil diunduh dan diekstrak ke ./data")
else:
    print("Direktori data sudah tersedia.")
# Out:
# Direktori data sudah tersedia.

# %% [markdown]
# ## Config
# Untuk memastikan tiap anggota kelompok melakukan konfigurasi yang sama pada data

# %%
CONFIG = {
    "IMG_SIZE": (64, 64),   #ukuran piksel tiap gambar di crop jadi 64x64 biar gk terlalu berat
    "XML_PATH": "./data/annotations.xml",
    "IMAGES_DIR": "./data/", # Path ini diperbaiki agar sesuai dengan struktur nama gambar di XML
    "RANDOM_STATE": 42, #yhh random seet ajah
    "LABEL_MAP": {
        "free_parking_space": 0,                # Kosong
        "not_free_parking_space": 1,            # Terisi
        "partially_free_parking_space": 1       # Terisi
    }
}

# %% [markdown]
# ## Sanity Check

# %%
import os
import xml.etree.ElementTree as ET

# Verifikasi keberadaan file utama
assert os.path.exists(CONFIG["XML_PATH"]), "File annotations.xml tidak ditemukan!"
assert os.path.exists(CONFIG["IMAGES_DIR"]), "Direktori citra tidak ditemukan!"

# Cek 1 sampel bounding box dari XML
tree = ET.parse(CONFIG["XML_PATH"])
root = tree.getroot()
first_image_node = root.find('image')

print(f"Sample Image Name : {first_image_node.get('name')}")
# Mengubah dari 'box' menjadi 'polygon' untuk mencocokkan struktur XML
print(f"Jumlah Anotasi Polygon: {len(first_image_node.findall('polygon'))}")
print("Lingkungan siap digunakan untuk modul pengerjaan.")
# Out:
# Sample Image Name : images/0.png
# Jumlah Anotasi Polygon: 28
# Lingkungan siap digunakan untuk modul pengerjaan.

# %%
import os
import cv2
import xml.etree.ElementTree as ET
import numpy as np

# 1. Menyiapkan direktori penyimpanan berdasarkan label biner
PROCESSED_DIR = "./data/processed"
os.makedirs(os.path.join(PROCESSED_DIR, "0"), exist_ok=True)
os.makedirs(os.path.join(PROCESSED_DIR, "1"), exist_ok=True)

# 2. Membaca struktur file anotasi XML
tree = ET.parse(CONFIG["XML_PATH"])
root = tree.getroot()

print("Memulai ekstraksi ROI petak parkir...")
total_extracted = 0

# 3. Iterasi untuk memproses setiap gambar yang tercatat di XML
for image_node in root.findall('image'):
    img_name = image_node.get('name')
    img_path = os.path.join(CONFIG["IMAGES_DIR"], img_name)
    img = cv2.imread(img_path)

    # Lewati jika file gambar asli tidak ditemukan di direktori
    if img is None:
        # print(f"Peringatan: Gambar tidak ditemukan di {img_path}, melewati.")
        continue

    # 4. Iterasi setiap polygon (sebelumnya kotak batas) di dalam gambar
    for idx, polygon_node in enumerate(image_node.findall('polygon')):
        label = polygon_node.get('label')

        # Konversi label teks menjadi angka (0 atau 1) menggunakan kontrak data
        num_label = CONFIG["LABEL_MAP"].get(label, 1)

        # Ambil titik koordinat polygon dari atribut 'points'
        points_str = polygon_node.get('points')

        # Parsing string points ke list of tuples (x, y)
        # Contoh: "54.80,9.10;137.90,7.60;141.12,204.87;55.80,205.70"
        points = []
        for pair in points_str.split(';') :
            x, y = map(float, pair.split(','))
            points.append((int(x), int(y)))

        # Ubah points menjadi array numpy untuk cv2.boundingRect
        points_np = np.array(points)

        # Hitung bounding box (xtl, ytl, width, height) yang mengelilingi polygon
        xtl, ytl, width, height = cv2.boundingRect(points_np)
        xbr, ybr = xtl + width, ytl + height

        # Cegah eror dengan memastikan koordinat tidak melampaui batas dimensi gambar asli
        img_height, img_width = img.shape[:2]
        ytl, ybr = max(0, ytl), min(img_height, ybr)
        xtl, xbr = max(0, xtl), min(img_width, xbr)

        # 5. Lakukan pemotongan (cropping) citra
        patch = img[ytl:ybr, xtl:xbr]

        # Abaikan jika hasil crop kosong (koordinat tidak valid atau terlalu kecil)
        if patch.size == 0 or patch.shape[0] < 5 or patch.shape[1] < 5: # Tambahkan validasi ukuran minimum
            # print(f"Peringatan: Patch kosong atau terlalu kecil untuk {img_name}, polygon {idx}, melewati.")
            continue

        # 6. Simpan potongan gambar (patch) ke direktori kelas yang sesuai
        # Membersihkan nama file jika img_name memiliki format folder seperti 'images/0.png'
        clean_name = img_name.replace("/", "_").replace("\\", "_").split('.')[0]
        patch_filename = f"{clean_name}_patch_{idx}.jpg"
        save_path = os.path.join(PROCESSED_DIR, str(num_label), patch_filename)

        cv2.imwrite(save_path, patch)
        total_extracted += 1

print(f"Proses selesai! Total {total_extracted} petak parkir berhasil diekstrak dan disimpan di {PROCESSED_DIR}.")
# Out:
# Memulai ekstraksi ROI petak parkir...
# Proses selesai! Total 902 petak parkir berhasil diekstrak dan disimpan di ./data/processed.

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Mendefinisikan jalur file gambar
image_path = "./data/images/0.png"

# Memeriksa apakah file gambar tersedia
if os.path.exists(image_path):
    # Membaca gambar menggunakan OpenCV
    img = cv2.imread(image_path)

    # Mengonversi ruang warna dari BGR (bawaan OpenCV) ke RGB (bawaan Matplotlib)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Menampilkan gambar
    plt.figure(figsize=(8, 6))
    plt.imshow(img_rgb)
    plt.title(f"Proses Ekstraksi Selesai: {os.path.basename(image_path)}")
    plt.axis('off')
    plt.show()
else:
    print(f"File {image_path} tidak ditemukan di direktori saat ini.")

# %%
# !ls -R ./data
# Out:
# ./data:
# annotations.xml  boxes	images	parking.csv  processed
#
# ./data/boxes:
# 0.png	12.png	15.png	19.png	21.png	25.png	28.png	30.png	3.png  6.png
# 10.png	13.png	17.png	1.png	22.png	26.png	29.png	31.png	4.png  8.png
# 11.png	14.png	18.png	20.png	24.png	27.png	2.png	32.png	5.png  9.png
#
# ./data/images:
# 0.png	12.png	15.png	19.png	21.png	25.png	28.png	30.png	3.png  6.png
# 10.png	13.png	17.png	1.png	22.png	26.png	29.png	31.png	4.png  8.png
# 11.png	14.png	18.png	20.png	24.png	27.png	2.png	32.png	5.png  9.png
#
# ./data/processed:
# 0  1
#
# ./data/processed/0:
# images_0_patch_0.jpg	images_26_patch_16.jpg	images_4_patch_27.jpg
# images_0_patch_1.jpg	images_26_patch_17.jpg	images_4_patch_28.jpg
# images_0_patch_27.jpg	images_26_patch_18.jpg	images_4_patch_29.jpg
# images_0_patch_2.jpg	images_26_patch_1.jpg	images_4_patch_2.jpg
# images_0_patch_3.jpg	images_26_patch_24.jpg	images_4_patch_30.jpg
# images_0_patch_4.jpg	images_26_patch_37.jpg	images_4_patch_31.jpg
# images_0_patch_5.jpg	images_26_patch_39.jpg	images_4_patch_32.jpg
# images_0_patch_6.jpg	images_26_patch_40.jpg	images_4_patch_3.jpg
# images_0_patch_7.jpg	images_26_patch_41.jpg	images_4_patch_40.jpg
# images_0_patch_8.jpg	images_26_patch_50.jpg	images_4_patch_41.jpg
# images_10_patch_3.jpg	images_26_patch_55.jpg	images_4_patch_45.jpg
# images_10_patch_4.jpg	images_26_patch_59.jpg	images_4_patch_4.jpg
# images_10_patch_5.jpg	images_26_patch_5.jpg	images_5_patch_10.jpg
# images_10_patch_6.jpg	images_26_patch_60.jpg	images_5_patch_11.jpg
# images_10_patch_9.jpg	images_26_patch_61.jpg	images_5_patch_13.jpg
# images_11_patch_11.jpg	images_26_patch_64.jpg	images_5_patch_14.jpg
# images_19_patch_27.jpg	images_29_patch_0.jpg	images_8_patch_2.jpg
# images_19_patch_28.jpg	images_29_patch_10.jpg	images_8_patch_3.jpg
# images_19_patch_29.jpg	images_29_patch_11.jpg	images_8_patch_4.jpg
# images_19_patch_2.jpg	images_29_patch_12.jpg	images_8_patch_6.jpg
# images_19_patch_3.jpg	images_29_patch_13.jpg	images_8_patch_7.jpg
# images_19_patch_4.jpg	images_29_patch_14.jpg	images_8_patch_8.jpg
# images_19_patch_5.jpg	images_29_patch_16.jpg	images_9_patch_0.jpg
# images_19_patch_6.jpg	images_29_patch_19.jpg	images_9_patch_10.jpg
# images_19_patch_7.jpg	images_29_patch_1.jpg	images_9_patch_11.jpg
# images_19_patch_8.jpg	images_29_patch_20.jpg	images_9_patch_12.jpg
# images_19_patch_9.jpg	images_29_patch_22.jpg	images_9_patch_13.jpg
# images_1_patch_0.jpg	images_29_patch_23.jpg	images_9_patch_14.jpg
# images_1_patch_10.jpg	images_29_patch_4.jpg	images_9_patch_15.jpg
# images_1_patch_11.jpg	images_29_patch_5.jpg	images_9_patch_16.jpg
# images_1_patch_12.jpg	images_29_patch_7.jpg	images_9_patch_17.jpg
# images_1_patch_13.jpg	images_29_patch_8.jpg	images_9_patch_18.jpg
# images_1_patch_16.jpg	images_29_patch_9.jpg	images_9_patch_20.jpg
# images_1_patch_17.jpg	images_2_patch_0.jpg	images_9_patch_21.jpg
# images_1_patch_19.jpg	images_2_patch_10.jpg	images_9_patch_23.jpg
# images_1_patch_1.jpg	images_2_patch_11.jpg	images_9_patch_2.jpg
# images_1_patch_20.jpg	images_2_patch_12.jpg	images_9_patch_5.jpg
# images_1_patch_22.jpg	images_2_patch_13.jpg	images_9_patch_7.jpg
# images_1_patch_23.jpg	images_2_patch_14.jpg	images_9_patch_8.jpg
# images_1_patch_24.jpg	images_2_patch_1.jpg

# %%
import xml.etree.ElementTree as ET

# Membaca struktur file anotasi XML
tree = ET.parse(CONFIG["XML_PATH"])
root = tree.getroot()

total_images_with_boxes = 0
total_boxes_found = 0 # Mengganti nama variabel menjadi total_polygons_found untuk kejelasan

# Iterasi setiap gambar yang tercatat di XML
for image_node in root.findall('image'):
    # Mengubah dari 'box' menjadi 'polygon' untuk mencocokkan struktur XML
    polygons = image_node.findall('polygon')
    if len(polygons) > 0:
        total_images_with_boxes += 1
        total_boxes_found += len(polygons)

print(f"Total gambar yang ditemukan dalam XML: {len(root.findall('image'))}")
print(f"Total gambar dengan setidaknya satu anotasi polygon: {total_images_with_boxes}")
print(f"Total anotasi polygon di seluruh gambar: {total_boxes_found}")

print("\n--- Detil Node Gambar Pertama ---")
first_image_node = root.find('image')
if first_image_node is not None:
    print(f"Nama Gambar: {first_image_node.get('name')}")
    print("Atribut Gambar:")
    for attr, value in first_image_node.items():
        print(f"  {attr}: {value}")
    # Mengubah dari 'box' menjadi 'polygon' untuk mencocokkan struktur XML
    polygons_in_first_image = first_image_node.findall('polygon')
    print(f"Jumlah Anotasi Polygon di Gambar Pertama: {len(polygons_in_first_image)}")
    if len(polygons_in_first_image) > 0:
        print("Detil Anotasi Polygon Pertama:")
        first_polygon = polygons_in_first_image[0]
        for attr, value in first_polygon.items():
            print(f"  {attr}: {value}")
    else:
        print("Tidak ada anotasi polygon ditemukan di gambar pertama ini.")
else:
    print("Tidak ada node 'image' ditemukan di XML.")
# Out:
# Total gambar yang ditemukan dalam XML: 30
# Total gambar dengan setidaknya satu anotasi polygon: 30
# Total anotasi polygon di seluruh gambar: 903
#
# --- Detil Node Gambar Pertama ---
# Nama Gambar: images/0.png
# Atribut Gambar:
#   id: 0
#   name: images/0.png
#   width: 1200
#   height: 621
# Jumlah Anotasi Polygon di Gambar Pertama: 28
# Detil Anotasi Polygon Pertama:
#   label: free_parking_space
#   occluded: 0
#   source: manual
#   points: 54.80,9.10;137.90,7.60;141.12,204.87;55.80,205.70
#   z_order: 0

# %%
import cv2
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import numpy as np

# Pilih nama gambar untuk divisualisasikan
image_to_visualize = 'images/0.png' # Kita bisa pilih gambar pertama sebagai contoh

# Membaca gambar
image_path = os.path.join(CONFIG["IMAGES_DIR"], image_to_visualize)
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Membaca anotasi XML
tree = ET.parse(CONFIG["XML_PATH"])
root = tree.getroot()

# Cari node gambar yang sesuai
image_node = None
for node in root.findall('image'):
    if node.get('name') == image_to_visualize:
        image_node = node
        break

if image_node is not None:
    # Buat salinan gambar untuk digambar anotasi
    img_with_annotations = img_rgb.copy()

    # Iterasi setiap polygon di gambar ini
    for polygon_node in image_node.findall('polygon'):
        points_str = polygon_node.get('points')
        label = polygon_node.get('label')

        # Parsing string points ke list of tuples (x, y)
        points = []
        for pair in points_str.split(';') :
            x, y = map(float, pair.split(','))
            points.append([int(x), int(y)]) # Menggunakan list of lists untuk cv2.polylines

        # Ubah points menjadi array numpy
        points_np = np.array(points, np.int32)
        points_np = points_np.reshape((-1, 1, 2)) # Reshape untuk cv2.polylines

        # Tentukan warna berdasarkan label
        color = (0, 255, 0) # Hijau untuk 'free_parking_space'
        if 'not_free_parking_space' in label:
            color = (255, 0, 0) # Merah untuk 'not_free_parking_space'
        elif 'partially_free_parking_space' in label:
            color = (255, 255, 0) # Kuning untuk 'partially_free_parking_space'

        # Gambar polygon
        cv2.polylines(img_with_annotations, [points_np], isClosed=True, color=color, thickness=2)

        # Tambahkan teks label (opsional)
        # Cari titik tengah polygon atau gunakan salah satu titik sudut untuk teks
        if points_np.size > 0:
            text_x, text_y = points_np[0][0][0], points_np[0][0][1] - 10 # Sedikit di atas titik pertama
            cv2.putText(img_with_annotations, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    # Tampilkan gambar dengan anotasi
    plt.figure(figsize=(10, 8))
    plt.imshow(img_with_annotations)
    plt.title(f"Gambar dengan Anotasi Polygon: {image_to_visualize}")
    plt.axis('off')
    plt.show()
else:
    print(f"Node gambar untuk {image_to_visualize} tidak ditemukan dalam annotations.xml.")

# %%
dddd
